# %% [markdown]
# <a href="https://www.kaggle.com/code/denizherand/bir-daha-dene?scriptVersionId=194321396" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ben deniyorum

# %%
y = 3.2
type(3.2)
# Out:
# float
